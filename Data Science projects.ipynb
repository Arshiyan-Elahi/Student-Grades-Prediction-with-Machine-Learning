# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle

data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/student-mat.csv")
data.head()

# %%
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
predict = "G3"

# Fix: Use 'axis=1' explicitly
x = np.array(data.drop([predict], axis=1))
y = np.array(data[predict])

# Splitting dataset into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %%
linear_regression = LinearRegression()
linear_regression.fit(xtrain, ytrain)
accuracy = linear_regression.score(xtest, ytest)
print(accuracy)

# %%
predictions = linear_regression.predict(xtest)
for i in range(len(predictions)):
    print(predictions[x], xtest[x], [ytest[x]])

# %%
import os

# Define the path where images and notebooks will be saved
save_path = "/content/drive/My Drive/Student_Grades_Project"

# Create folder if it does not exist
if not os.path.exists(save_path):
    os.makedirs(save_path)

print(f"📂 Folder Created: {save_path}")

# %%
import shutil
import os

# Google Drive folder where notebook will be saved
save_path = "/content/drive/MyDrive/Student_Grades_Project"

# Ensure folder exists
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Correct source notebook path (Colab notebook path)
notebook_path = "/content/Data Science projects.ipynb"  # Your current Colab notebook

# Destination path in Google Drive
save_notebook_path = os.path.join(save_path, "Data Science projects.ipynb")

# Copy the notebook file to the Google Drive folder
shutil.copy(notebook_path, save_notebook_path)

print(f"📄 Notebook saved to: {save_notebook_path}")

# %%
import pandas as pd
import plotly.express as px

# Load dataset
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/student-mat.csv")

# Scatter Plot: Relationship between G1 and G3
scatter_fig = px.scatter(data, x="G1", y="G3", title="Scatter Plot: G1 vs G3 (First Exam vs Final Exam)")

# Bar Chart: Average G3 Score per Study Time
bar_fig = px.bar(data.groupby("studytime")["G3"].mean().reset_index(),
                 x="studytime", y="G3", title="Average Final Grade (G3) vs Study Time")

# Line Chart: G1, G2, and G3 Trends
line_fig = px.line(data, x=data.index, y=["G1", "G2", "G3"], title="Trend of G1, G2, and G3 Over Time")

# Histogram: Distribution of Final Grades (G3)
hist_fig = px.histogram(data, x="G3", nbins=10, title="Distribution of Final Grades (G3)")

# Box Plot: Study Time vs Final Grade (G3)
box_fig = px.box(data, x="studytime", y="G3", title="Study Time vs Final Grades (G3)")

# Display all graphs
scatter_fig.show()
bar_fig.show()
line_fig.show()
hist_fig.show()
box_fig.show()
